# %%
#Problem 1

# %%
ice_cream_rating = 8.5

# %%
sleeping_rating = 9

# %%
#Problem 2

# %%
first_name = input("What's your first name? ")
last_name = input("What's your last name? ")
# Out:
# What's your first name?  Daniel
# What's your last name?  Jarrad

# %%
my_name = first_name + " " + last_name
print(my_name)
# Out:
# Daniel Jarrad

# %%
#Problem 3

# %%
happiness_rating = (ice_cream_rating + sleeping_rating) / 2
print(happiness_rating)
# Out:
# 8.75

# %%
#Problem 4

# %% [markdown]
# print(type(ice_cream_rating))
# print(type(first_name))
# print(type(happiness_rating))

# %%
#Problem 5

# %%
print('My name is', first_name, 'and I give eating ice cream a score of', ice_cream_rating, 'out of 10!')
print('I am', my_name, 'and my sleeping enjoyment rating is', sleeping_rating, '/ 10!')
print('Based on the factors above, my happiness rating is', happiness_rating, 'out of 10, or 87.5%!')
# Out:
# My name is Daniel and I give eating ice cream a score of 8.5 out of 10!
# I am Daniel Jarrad and my sleeping enjoyment rating is 9 / 10!
# Based on the factors above, my happiness rating is 8.75 out of 10, or 87.5%!
